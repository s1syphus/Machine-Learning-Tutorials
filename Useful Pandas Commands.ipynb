# %% [markdown]
# # Useful Pandas Commands
#
# "pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language."
#
# http://pandas.pydata.org/
#
# This notebook will contain some useful/common pandas commands

# %%
import pandas as pd
my_array = pd.read_csv('Data/DecisionTreeData/restaurant_data.csv')

# %%
my_array
# Out:
#    alternate  bar friday_saturday hungry patrons price rain reservation  \
# 0        yes   no              no    yes    some   $$$   no         yes
# 1        yes   no              no    yes    full     $   no          no
# 2         no  yes              no     no    some     $   no          no
# 3        yes   no             yes    yes    full     $  yes          no
# 4        yes   no             yes     no    full   $$$   no         yes
# 5         no  yes              no    yes    some    $$  yes         yes
# 6         no  yes              no     no    none     $  yes          no
# 7         no   no              no    yes    some    $$  yes         yes
# 8         no  yes             yes     no    full     $  yes          no
# 9        yes  yes             yes    yes    full   $$$   no         yes
# 10        no   no              no     no    none     $   no          no
# 11       yes  yes             yes    yes    full     $   no          no
#
#        type wait_est will_wait
# ...

# %%
my_array['will_wait']
# Out:
# 0     yes
# 1      no
# 2     yes
# 3     yes
# 4      no
# 5     yes
# 6      no
# 7     yes
# 8      no
# 9      no
# 10     no
# 11    yes
# Name: will_wait, dtype: object

# %%
my_array[my_array['will_wait'] == 'yes']
# Out:
#    alternate  bar friday_saturday hungry patrons price rain reservation  \
# 0        yes   no              no    yes    some   $$$   no         yes
# 2         no  yes              no     no    some     $   no          no
# 3        yes   no             yes    yes    full     $  yes          no
# 5         no  yes              no    yes    some    $$  yes         yes
# 7         no   no              no    yes    some    $$  yes         yes
# 11       yes  yes             yes    yes    full     $   no          no
#
#        type wait_est will_wait
# 0    French     0-10       yes
# 2    Burger     0-10       yes
# 3      Thai    10-30       yes
# 5   Italian     0-10       yes
# 7      Thai     0-10       yes
# 11   Burger    30-60       yes

# %%
my_array['will_wait'].value_counts()
# Out:
# no     6
# yes    6
# Name: will_wait, dtype: int64

# %%
my_array['will_wait'].value_counts()['yes']
# Out:
# 6
